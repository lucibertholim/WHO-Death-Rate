# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Resources/HDI_countries.csv', encoding ='ISO-8859-1', skiprows=1)

# %%
df.head()
# Out:
#    HDI Rank (2017)       Country   1990   1991   1992   1993   1994   1995  \
# 0              168   Afghanistan    NaN    NaN    NaN    NaN    NaN    NaN
# 1               68       Albania  0.645  0.626  0.610  0.613  0.619  0.632
# 2               85       Algeria  0.577  0.581  0.587  0.591  0.595  0.600
# 3               35       Andorra    NaN    NaN    NaN    NaN    NaN    NaN
# 4              147        Angola    NaN    NaN    NaN    NaN    NaN    NaN
#
#     1996   1997  ...   2008   2009   2010   2011   2012   2013   2014   2015  \
# 0    NaN    NaN  ...  0.437  0.453  0.463  0.471  0.482  0.487  0.491  0.493
# 1  0.641  0.641  ...  0.724  0.729  0.741  0.752  0.767  0.771  0.773  0.776
# 2  0.608  0.617  ...  0.709  0.719  0.729  0.736  0.740  0.745  0.747  0.749
# 3    NaN    NaN  ...  0.831  0.830  0.828  0.827  0.849  0.850  0.853  0.854
# 4    NaN    NaN  ...  0.502  0.522  0.520  0.535  0.543  0.554  0.564  0.572
#
#     2016   2017
# 0  0.494  0.498
# 1  0.782  0.785
# ...

# %%
country=df['Country'].str.lstrip()
df['Country']=country

# %%
df2=df[['Country','2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016']]

# %%
list(df2)
# Out:
# ['Country',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016']

# %%
df3=pd.melt(df2, id_vars=['Country'], value_vars=['2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016'])

# %%
df3.head(250)
# Out:
#                                 Country variable  value
# 0                           Afghanistan     2000    NaN
# 1                               Albania     2000  0.669
# 2                               Algeria     2000  0.644
# 3                               Andorra     2000  0.759
# 4                                Angola     2000  0.387
# 5                   Antigua and Barbuda     2000    NaN
# 6                             Argentina     2000  0.771
# 7                               Armenia     2000  0.647
# 8                             Australia     2000  0.898
# 9                               Austria     2000  0.838
# 10                           Azerbaijan     2000  0.640
# 11                              Bahamas     2000  0.776
# 12                              Bahrain     2000  0.792
# 13                           Bangladesh     2000  0.468
# 14                             Barbados     2000  0.752
# 15                              Belarus     2000  0.683
# ...

# %%
df3.to_csv('HDI_clean.csv')

# %%
#calculating correlation
df4=df2=df[['Country','2016']]

# %%
df4.columns=['Country', 'HDI']

# %%
df4.head()
# Out:
#        Country    HDI
# 0  Afghanistan  0.494
# 1      Albania  0.782
# 2      Algeria  0.753
# 3      Andorra  0.856
# 4       Angola  0.577

# %%
df_ASDR=pd.read_csv('Output_files/ASDR_clean.csv')

# %%
df_ASDR.head()
# Out:
#    Unnamed: 0              Country  Population    variable      2000  \
# 0           0          Afghanistan       20094  All Causes   1617.46
# 1           1              Albania        3122  All Causes  766.3497
# 2           2              Algeria       31184  All Causes  814.9004
# 3           3               Angola       16441  All Causes  2014.845
# 4           4  Antigua and Barbuda          84  All Causes  779.1912
#
#        2010      2016
# 0  1327.411  1254.805
# 1  678.7701  609.1701
# 2  613.4972  558.7889
# 3  1372.689  1181.017
# 4  657.0445  667.1831

# %%
list(df_ASDR)
# Out:
# ['Unnamed: 0', 'Country', 'Population', 'variable', '2000', '2010', '2016']

# %%
df_ASDR2=df_ASDR.merge(df4,how='left',on='Country')

# %%
df_ASDR2.head()
# Out:
#    Unnamed: 0              Country  Population    variable      2000  \
# 0           0          Afghanistan       20094  All Causes   1617.46
# 1           1              Albania        3122  All Causes  766.3497
# 2           2              Algeria       31184  All Causes  814.9004
# 3           3               Angola       16441  All Causes  2014.845
# 4           4  Antigua and Barbuda          84  All Causes  779.1912
#
#        2010      2016    HDI
# 0  1327.411  1254.805  0.494
# 1  678.7701  609.1701  0.782
# 2  613.4972  558.7889  0.753
# 3  1372.689  1181.017  0.577
# 4  657.0445  667.1831  0.778

# %%
df_ASDR_infectious=df_ASDR2.loc[df_ASDR['variable']=='Infectious and parasitic diseases']

# %%
df_ASDR_infectious.head()
# Out:
#      Unnamed: 0              Country  Population  \
# 366         366          Afghanistan       20094
# 367         367              Albania        3122
# 368         368              Algeria       31184
# 369         369               Angola       16441
# 370         370  Antigua and Barbuda          84
#
#                               variable      2000      2010      2016    HDI
# 366  Infectious and parasitic diseases  315.0906  177.0181   118.898  0.494
# 367  Infectious and parasitic diseases   8.43844  4.951194  4.420543  0.782
# 368  Infectious and parasitic diseases   37.6914  22.10954  17.60994  0.753
# 369  Infectious and parasitic diseases  707.6833  441.3142  362.8709  0.577
# 370  Infectious and parasitic diseases  34.33326  30.37699  30.31673  0.778

# %%
plt.scatter(df_ASDR_infectious['HDI'], df_ASDR_infectious['2016'], marker="o", facecolors="red")
plt.xlim(min(df_ASDR_infectious['HDI'])-0.1,max(df_ASDR_infectious['HDI'])+0.1)
#plt.ylim(min(sales)-50,max(sales)+50)
plt.title("Human Devepment Index vs Infectious Diseases Death Rate")
plt.xlabel ("HDI vs temperature")
plt.ylabel ("Infectious Diseases Death Rate per 100,000 pop")
plt.figure(figsize=(30,15))
plt.show()

# %%
plt.xcorr(df_ASDR_infectious['HDI'], df_ASDR_infectious['2016'], marker="o", facecolors="red")
plt.xlim(min(df_ASDR_infectious['HDI'])-0.1,max(df_ASDR_infectious['HDI'])+0.1)
#plt.ylim(min(sales)-50,max(sales)+50)
plt.title("Human Devepment Index vs Infectious Diseases Death Rate")
plt.xlabel ("HDI vs temperature")
plt.ylabel ("Infectious Diseases Death Rate per 100,000 pop")
plt.figure(figsize=(30,15))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-7fc904f8bb93> in <module>
# ----> 1 plt.xcorr(df_ASDR_infectious['HDI'], df_ASDR_infectious['2016'], marker="o", facecolors="red")
#       2 plt.xlim(min(df_ASDR_infectious['HDI'])-0.1,max(df_ASDR_infectious['HDI'])+0.1)
#       3 #plt.ylim(min(sales)-50,max(sales)+50)
#       4 plt.title("Human Devepment Index vs Infectious Diseases Death Rate")
#       5 plt.xlabel ("HDI vs temperature")
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in xcorr(x, y, normed, detrend, usevlines, maxlags, data, **kwargs)
#    3045         x, y, normed=normed, detrend=detrend, usevlines=usevlines,
#    3046         maxlags=maxlags, **({"data": data} if data is not None else
# -> 3047         {}), **kwargs)
#    3048
#    3049
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...
