# %%
import pandas as pd

# %%
xls = pd.ExcelFile('GHE2016_Death-Rates-country.xls')

# %%
df2016 = pd.read_excel(xls, 'ASDR2016', index_col=None, header=None)

# %%
df2016.head(20)
# Out:
#         0         1    2                                                  3    \
# 0       NaN       NaN  NaN                          World Health Organization
# 1       NaN       NaN  NaN   Department of Information, Evidence and Research
# 2       NaN       NaN  NaN                                         April 2018
# 3       NaN       NaN  NaN                                                NaN
# 4       NaN       NaN  NaN  Age-standardized rate per 100 000 population b...
# 5       NaN       NaN  NaN                     and WHO Member State (1), 2016
# 6       Sex  GHE code  NaN                                          GHE cause
# 7       NaN       NaN  NaN                                                NaN
# 8       NaN       NaN  NaN                                                NaN
# 9   Persons       NaN  NaN                              Population ('000) (2)
# 10  Persons         0  NaN                                         All Causes
# ...

# %%
df2016_1=df2016.drop(df2016.index[0:6])
df2016_1.head()
# Out:
#         0         1    2                      3    4    5    \
# 6       Sex  GHE code  NaN              GHE cause  NaN  NaN
# 7       NaN       NaN  NaN                    NaN  NaN  NaN
# 8       NaN       NaN  NaN                    NaN  NaN  NaN
# 9   Persons       NaN  NaN  Population ('000) (2)  NaN  NaN
# 10  Persons         0  NaN             All Causes  NaN  NaN
#
#                                                   6            7        8    \
# 6   Member State\n(See Notes for explanation of co...  Afghanistan  Albania
# 7                                          ISO-3 Code          AFG      ALB
# 8                                                 NaN            4        3
# 9                                                 NaN        34656     2926
# 10                                                NaN      1254.81   609.17
#
#         9    ...                          180                       181  \
# ...

# %%
import numpy as np
df2016_1 = df2016_1.replace(np.nan, '', regex=True)
df2016_1.head(20)
# Out:
#         0         1   2                                                  3    \
# 6       Sex  GHE code                                              GHE cause
# 7
# 8
# 9   Persons                                            Population ('000) (2)
# 10  Persons         0                                             All Causes
# 11  Persons        10  I.  Communicable, maternal, perinatal and nutritio...
# 12  Persons        20                                                     A.
# 13  Persons        30
# 14  Persons        40
# 15  Persons        50
# 16  Persons        60
# 17  Persons        70
# 18  Persons        80
# 19  Persons        85
# 20  Persons        90
# 21  Persons       100
# 22  Persons       110
# 23  Persons       120
# 24  Persons       130
# 25  Persons       140
#
#                                   4                           5    \
# 6
# 7
# 8
# 9
# 10
# 11
# 12  Infectious and parasitic diseases
# ...

# %%
df2016_1["disease"] = df2016_1[3].map(str) + " " + df2016_1[4].map(str) + " " + df2016_1[5].map(str) + " " + df2016_1[6].map(str)

# %%
df2016_1.head(20)
# Out:
#           0         1   2                                                  3  \
# 6       Sex  GHE code                                              GHE cause
# 7
# 8
# 9   Persons                                            Population ('000) (2)
# 10  Persons         0                                             All Causes
# 11  Persons        10  I.  Communicable, maternal, perinatal and nutritio...
# 12  Persons        20                                                     A.
# 13  Persons        30
# 14  Persons        40
# 15  Persons        50
# 16  Persons        60
# 17  Persons        70
# 18  Persons        80
# 19  Persons        85
# 20  Persons        90
# 21  Persons       100
# 22  Persons       110
# 23  Persons       120
# 24  Persons       130
# 25  Persons       140
#
#                                     4                           5  \
# 6
# 7
# 8
# 9
# 10
# 11
# 12  Infectious and parasitic diseases
# ...

# %%
df2016_1b=df2016_1.drop([1,2,3,4,5,6], axis = 1)

# %%
#df2016_loc2=df2016_loc1.loc
df2016_1b.columns=df2016_1b.iloc[0]
df2016_1b.head(20)
# Out:
# 6       Sex  Afghanistan    Albania    Algeria     Angola  \
# 6       Sex  Afghanistan    Albania    Algeria     Angola
# 7                    AFG        ALB        DZA        AGO
# 8                      4          3          4          4
# 9   Persons        34656       2926      40606      28813
# 10  Persons      1254.81     609.17    558.789    1181.02
# 11  Persons      249.939    24.2395    65.8108    555.151
# 12  Persons      118.898    4.42054    17.6099    362.871
# 13  Persons      77.6604   0.201588    9.40724    129.415
# 14  Persons      3.78137   0.022059   0.212121    5.43998
# 15  Persons      3.72313  0.0124201   0.196998    5.20334
# 16  Persons    0.0113843  0.0018537  0.0028891  0.0460239
# 17  Persons     0.031293  0.0053908  0.0083387   0.129119
# 18  Persons            .          .          .          .
# 19  Persons            .          .          .          .
# 20  Persons    0.0155609  0.0023945  0.0038948  0.0614987
# ...

# %%
df2016_2=df2016_1b.drop(df2016_1b.index[0])
df2016_2.head(20)
# Out:
# 6       Sex Afghanistan    Albania    Algeria     Angola Antigua and Barbuda  \
# 7                   AFG        ALB        DZA        AGO                 ATG
# 8                     4          3          4          4                   2
# 9   Persons       34656       2926      40606      28813                 101
# 10  Persons     1254.81     609.17    558.789    1181.02             667.183
# 11  Persons     249.939    24.2395    65.8108    555.151             78.2323
# 12  Persons     118.898    4.42054    17.6099    362.871             30.3167
# 13  Persons     77.6604   0.201588    9.40724    129.415           0.0275204
# 14  Persons     3.78137   0.022059   0.212121    5.43998           0.0056367
# 15  Persons     3.72313  0.0124201   0.196998    5.20334           0.0056367
# 16  Persons   0.0113843  0.0018537  0.0028891  0.0460239                   .
# 17  Persons    0.031293  0.0053908  0.0083387   0.129119                   .
# ...

# %%
df2016_3=df2016_2.loc[df2016_2['Sex']=="Persons"]
df2016_3
# Out:
# 6        Sex Afghanistan    Albania    Algeria     Angola Antigua and Barbuda  \
# 9    Persons       34656       2926      40606      28813                 101
# 10   Persons     1254.81     609.17    558.789    1181.02             667.183
# 11   Persons     249.939    24.2395    65.8108    555.151             78.2323
# 12   Persons     118.898    4.42054    17.6099    362.871             30.3167
# 13   Persons     77.6604   0.201588    9.40724    129.415           0.0275204
# 14   Persons     3.78137   0.022059   0.212121    5.43998           0.0056367
# 15   Persons     3.72313  0.0124201   0.196998    5.20334           0.0056367
# 16   Persons   0.0113843  0.0018537  0.0028891  0.0460239                   .
# 17   Persons    0.031293  0.0053908  0.0083387   0.129119                   .
# 18   Persons           .          .          .          .                   .
# 19   Persons           .          .          .          .                   .
# ...

# %%
df2016_4=df2016_3.drop(['Sex'], axis=1)

# %%
df2016_transposed=df2016_4.set_index('GHE cause   Member State\n(See Notes for explanation of colour codes)').T

# %%
df2016_transposed.head(20)
# Out:
# GHE cause   Member State
# (See Notes for explanation of colour codes) Population ('000) (2)     \
# 6
# Afghanistan                                                                             34656
# Albania                                                                                  2926
# Algeria                                                                                 40606
# Angola                                                                                  28813
# Antigua and Barbuda                                                                       101
# Argentina                                                                               43847
# Armenia                                                                                  2925
# Australia                                                                               24126
# Austria                                                                                  8712
# ...

# %%
df2016_transposed.to_csv("ASDR2016_clean.csv")
