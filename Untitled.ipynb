# %%
import pandas as pd

# %%
df=pd.read_csv('Resources/ghe2016_deaths_country_allages.csv')

# %%
df.head()
# Out:
#   iso3  cause2015                                          causename   sex  \
# 0  AFG          0                                         All Causes  BTSX
# 1  AFG          0                                         All Causes  FMLE
# 2  AFG          0                                         All Causes   MLE
# 3  AFG         10  Communicable, maternal, perinatal and nutritio...  BTSX
# 4  AFG         10  Communicable, maternal, perinatal and nutritio...  FMLE
#
#    age agegroup       dths2000    low2000     upp2000       dths2001  ...  \
# 0   99   AGEAll  239647.000000  210309.55  272668.280  245432.671875  ...
# 1   99   AGEAll  113851.320312  100009.72  129574.590  116775.023438  ...
# 2   99   AGEAll  125795.671875  110487.74  143163.230  128657.656250  ...
# 3   99   AGEAll  147164.015625  126559.47  170114.450  150989.515625  ...
# 4   99   AGEAll   75758.437500   65171.02   87545.391   77510.140625  ...
#
# ...

# %%
df2=df.loc[df['sex']=='BTSX']

# %%
df_code=pd.read_csv('Resources/countries_codes_and_coordinates.csv')
df_code2=df_code.rename(columns={'Alpha-3 code':'iso3'})
iso3=df_code2['iso3'].str.lstrip()
df_code2['iso3']=iso3
df3=df2.merge(df_code2, how='left', on='iso3')

# %%
df3.head()
# Out:
#   iso3  cause2015                                          causename   sex  \
# 0  AFG          0                                         All Causes  BTSX
# 1  AFG         10  Communicable, maternal, perinatal and nutritio...  BTSX
# 2  AFG         20                  Infectious and parasitic diseases  BTSX
# 3  AFG         30                                       Tuberculosis  BTSX
# 4  AFG         40                                 STDs excluding HIV  BTSX
#
#    age agegroup       dths2000       low2000      upp2000       dths2001  ...  \
# 0   99   AGEAll  239647.000000  210309.55000  272668.2800  245432.671875  ...
# 1   99   AGEAll  147164.015625  126559.47000  170114.4500  150989.515625  ...
# 2   99   AGEAll   67082.507812   53817.42600   82106.6800   69451.906250  ...
# 3   99   AGEAll   13960.777344    8079.28520   21423.1150   13447.637695  ...
# 4   99   AGEAll    1563.436890     835.58746    2867.4226    1648.490234  ...
#
# ...

# %%
df4=df3[['Country',
 'causename',
 'dths2000',
 'dths2001',
 'dths2002',
 'dths2003',
 'dths2004',
 'dths2005',
 'dths2006',
 'dths2007',
 'dths2008',
 'dths2009',
 'dths2010',
 'dths2011',
 'dths2012',
 'dths2013',
 'dths2014',
 'dths2015',
 'dths2016']]

# %%
df4.head()
# Out:
#        Country                                          causename  \
# 0  Afghanistan                                         All Causes
# 1  Afghanistan  Communicable, maternal, perinatal and nutritio...
# 2  Afghanistan                  Infectious and parasitic diseases
# 3  Afghanistan                                       Tuberculosis
# 4  Afghanistan                                 STDs excluding HIV
#
#         dths2000       dths2001       dths2002       dths2003       dths2004  \
# 0  239647.000000  245432.671875  237810.093750  233742.953125  236298.718750
# 1  147164.015625  150989.515625  143539.828125  134649.640625  131553.750000
# 2   67082.507812   69451.906250   60822.589844   49975.062500   44947.789062
# 3   13960.777344   13447.637695   12772.646484   13529.087891   12492.741211
# 4    1563.436890    1648.490234    1762.734375    1936.947754    2138.156982
#
#         dths2005       dths2006       dths2007       dths2008       dths2009  \
# ...

# %%
df_pop=pd.read_csv('Resources/Population_countries.csv')

# %%
df_pop.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2009  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101453.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  ...  28004331.0
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0  ...  22549547.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2927519.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     84462.0
#
#          2010        2011        2012        2013        2014        2015  \
# ...

# %%
df_pop2=df_pop.rename(columns={'Country Name':'Country'})

# %%
df_pop3=df_pop2[['Country',
 '2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016']]

# %%
#df_pop2=df_pop.loc[df_pop['Series']=='Population mid-year estimates (millions)']

# %%
#df_pop3=df_pop2[['Region/Country/Area', 'Year', 'Value']]

# %%
#df_pop4=df_pop3.pivot(index='Region/Country/Area', columns='Year', values='Value')

# %%
#df_pop5=df_pop4.reset_index()
#df_pop6=df_pop5.rename(columns={'Region/Country/Area':'Country'})
#df_pop6.head()
# Out:
# Year         Country  2000 2001 2002 2003 2004    2005 2006 2007 2008 2009  \
# 0        Afghanistan   NaN  NaN  NaN  NaN  NaN   25.07  NaN  NaN  NaN  NaN
# 1             Africa   NaN  NaN  NaN  NaN  NaN  924.76  NaN  NaN  NaN  NaN
# 2            Albania   NaN  NaN  NaN  NaN  NaN    3.08  NaN  NaN  NaN  NaN
# 3            Algeria   NaN  NaN  NaN  NaN  NaN   33.29  NaN  NaN  NaN  NaN
# 4     American Samoa  0.06  NaN  NaN  NaN  NaN    0.06  NaN  NaN  NaN  NaN
#
# Year      2010 2011 2012 2013 2014      2015  2016 2017      2018
# 0         28.8  NaN  NaN  NaN  NaN     33.74   NaN  NaN     36.37
# 1     1,049.45  NaN  NaN  NaN  NaN  1,194.37   NaN  NaN  1,287.92
# 2         2.94  NaN  NaN  NaN  NaN      2.92   NaN  NaN      2.93
# 3        36.12  NaN  NaN  NaN  NaN     39.87   NaN  NaN     42.01
# 4         0.06  NaN  NaN  NaN  NaN      0.06  0.06  NaN      0.06

# %%
df_pop3.head()
# Out:
#        Country        2000        2001        2002        2003        2004  \
# 0        Aruba     90853.0     92898.0     94992.0     97017.0     98737.0
# 1  Afghanistan  20093756.0  20966463.0  21979923.0  23064851.0  24118979.0
# 2       Angola  16440924.0  16983266.0  17572649.0  18203369.0  18865716.0
# 3      Albania   3089027.0   3060173.0   3051010.0   3039616.0   3026939.0
# 4      Andorra     65390.0     67341.0     70049.0     73182.0     76244.0
#
#          2005        2006        2007        2008        2009        2010  \
# 0    100031.0    100832.0    101220.0    101353.0    101453.0    101669.0
# 1  25070798.0  25893450.0  26616792.0  27294031.0  28004331.0  28803167.0
# 2  19552542.0  20262399.0  20997687.0  21759420.0  22549547.0  23369131.0
# 3   3011487.0   2992547.0   2970017.0   2947314.0   2927519.0   2913021.0
# 4     78867.0     80991.0     82683.0     83861.0     84462.0     84449.0
#
# ...

# %%
df_pop3.columns=['Country',
 '2000_pop',
 '2001_pop',
 '2002_pop',
 '2003_pop',
 '2004_pop',
 '2005_pop',
 '2006_pop',
 '2007_pop',
 '2008_pop',
 '2009_pop',
 '2010_pop',
 '2011_pop',
 '2012_pop',
 '2013_pop',
 '2014_pop',
 '2015_pop',
 '2016_pop']

# %%
df5=df4.merge(df_pop3, how='left', on='Country')

# %%
df5.head(100)
# Out:
#         Country                                          causename  \
# 0   Afghanistan                                         All Causes
# 1   Afghanistan  Communicable, maternal, perinatal and nutritio...
# 2   Afghanistan                  Infectious and parasitic diseases
# 3   Afghanistan                                       Tuberculosis
# 4   Afghanistan                                 STDs excluding HIV
# 5   Afghanistan                                           Syphilis
# 6   Afghanistan                                          Chlamydia
# 7   Afghanistan                                         Gonorrhoea
# 8   Afghanistan                                     Trichomoniasis
# 9   Afghanistan                                     Genital herpes
# 10  Afghanistan                                         Other STDs
# 11  Afghanistan                                           HIV/AIDS
# 12  Afghanistan                                Diarrhoeal diseases
# ...

# %%
#cols = df5.columns.drop(['Country', 'causename'])
#df5[cols] = df5[cols].apply(pd.to_numeric, errors='coerce')

# %%
year_list=['2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016']


for year in year_list:
    df5[year]=(df5['dths'+year]/df5[year+'_pop'])*100000

# %%
df5.head()
# Out:
#        Country                                          causename  \
# 0  Afghanistan                                         All Causes
# 1  Afghanistan  Communicable, maternal, perinatal and nutritio...
# 2  Afghanistan                  Infectious and parasitic diseases
# 3  Afghanistan                                       Tuberculosis
# 4  Afghanistan                                 STDs excluding HIV
#
#         dths2000       dths2001       dths2002       dths2003       dths2004  \
# 0  239647.000000  245432.671875  237810.093750  233742.953125  236298.718750
# 1  147164.015625  150989.515625  143539.828125  134649.640625  131553.750000
# 2   67082.507812   69451.906250   60822.589844   49975.062500   44947.789062
# 3   13960.777344   13447.637695   12772.646484   13529.087891   12492.741211
# 4    1563.436890    1648.490234    1762.734375    1936.947754    2138.156982
#
#         dths2005       dths2006       dths2007  ...        2007        2008  \
# ...

# %%
df6=df5[['Country',
 'causename',
 '2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016']]

# %%
df6.head()
# Out:
#        Country                                          causename  \
# 0  Afghanistan                                         All Causes
# 1  Afghanistan  Communicable, maternal, perinatal and nutritio...
# 2  Afghanistan                  Infectious and parasitic diseases
# 3  Afghanistan                                       Tuberculosis
# 4  Afghanistan                                 STDs excluding HIV
#
#           2000         2001         2002         2003        2004        2005  \
# 0  1192.644123  1170.596451  1081.942342  1013.416272  979.721068  952.217957
# 1   732.386795   720.147769   653.049731   583.787169  545.436646  520.940052
# 2   333.847529   331.252373   276.718849   216.671950  186.358589  174.989148
# 3    69.478187    64.138800    58.110515    58.656732   51.796310   47.514201
# 4     7.780710     7.862510     8.019748     8.397833    8.865039    8.964597
#
#          2006        2007        2008        2009        2010        2011  \
# ...

# %%
df6.to_csv('CDR_clean.csv')

# %%
df7=pd.melt(df6, id_vars=['Country','causename'], value_vars=['2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016'])

# %%
df7.columns=['Country','Variable','Date','Crude Death Rate']

# %%
df7
# Out:
#             Country                                           Variable  Date  \
# 0       Afghanistan                                         All Causes  2000
# 1       Afghanistan  Communicable, maternal, perinatal and nutritio...  2000
# 2       Afghanistan                  Infectious and parasitic diseases  2000
# 3       Afghanistan                                       Tuberculosis  2000
# 4       Afghanistan                                 STDs excluding HIV  2000
# 5       Afghanistan                                           Syphilis  2000
# 6       Afghanistan                                          Chlamydia  2000
# 7       Afghanistan                                         Gonorrhoea  2000
# 8       Afghanistan                                     Trichomoniasis  2000
# 9       Afghanistan                                     Genital herpes  2000
# 10      Afghanistan                                         Other STDs  2000
# ...

# %%
df7['Date'] = df7['Date'].apply(pd.to_numeric, errors='coerce')

# %%
df7.dtypes
# Out:
# Country              object
# Variable             object
# Date                  int64
# Crude Death Rate    float64
# dtype: object

# %%
#Replacing United States by UNited States of America to merge with ASDR df
df8=df7.replace('United States', "United States of America")

# %%
df8['Country'].unique()
# Out:
# array(['Afghanistan', 'Angola', 'Albania', 'United Arab Emirates',
#        'Argentina', 'Armenia', 'Antigua and Barbuda', 'Australia',
#        'Austria', 'Azerbaijan', 'Burundi', 'Belgium', 'Benin',
#        'Burkina Faso', 'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize',
#        'Bolivia, Plurinational State of', 'Bolivia', 'Brazil', 'Barbados',
#        'Brunei Darussalam', 'Brunei', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland', 'Chile',
#        'China', "Côte d'Ivoire", 'Ivory Coast', 'Cameroon',
#        'Congo, the Democratic Republic of the', 'Congo', 'Colombia',
#        'Comoros', 'Cape Verde', 'Costa Rica', 'Cuba', 'Cyprus',
#        'Czech Republic', 'Germany', 'Djibouti', 'Denmark',
#        'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt', 'Eritrea',
#        'Spain', 'Estonia', 'Ethiopia', 'Finland', 'Fiji', 'France',
# ...

# %%
df8.to_csv('CRD_clean_tableau_format.csv')

# %%
df_ASDR=pd.read_csv('Output_files/ASDR_clean_tableau_format.csv')

# %%
variable=df_ASDR['Variable'].str.rstrip()
df_ASDR['Variable']=variable

# %%
df_ASDR['Variable'].unique()
# Out:
# array(['All Causes',
#        'Communicable, maternal, perinatal and nutritional conditions',
#        'Infectious and parasitic diseases', 'Tuberculosis',
#        'STDs excluding HIV', 'Syphilis', 'Chlamydia', 'Gonorrhoea',
#        'Trichomoniasis', 'Genital herpes', 'Other STDs', 'HIV/AIDS',
#        'Diarrhoeal diseases', 'Childhood-cluster diseases',
#        'Whooping cough', 'Diphtheria', 'Measles', 'Tetanus', 'Meningitis',
#        'Encephalitis', 'Hepatitis', 'Acute hepatitis A',
#        'Acute hepatitis B', 'Acute hepatitis C', 'Acute hepatitis E',
#        'Parasitic and vector diseases', 'Malaria',
#        'African Trypanosomiasis', 'Chagas disease', 'Schistosomiasis',
#        'Leishmaniasis', 'lymphatic filariasis', 'Onchocerciasis',
#        'Cysticercosis', 'Echinococcosis', 'Dengue', 'Trachoma',
#        'Yellow fever', 'Rabies', 'Intestinal nematode infections',
#        'Ascariasis', 'Trichuriasis', 'Hookworm disease',
# ...

# %%
df_ASDR.head()
# Out:
#    Unnamed: 0              Country  Population    Variable  Date  \
# 0           0          Afghanistan       20094  All Causes  2000
# 1           1              Albania        3122  All Causes  2000
# 2           2              Algeria       31184  All Causes  2000
# 3           3               Angola       16441  All Causes  2000
# 4           4  Antigua and Barbuda          84  All Causes  2000
#
#   Age-standardized Death Rate
# 0                     1617.46
# 1                    766.3497
# 2                    814.9004
# 3                    2014.845
# 4                    779.1912

# %%
df_ASDR_CDR=df8.merge(df_ASDR, how='outer', on=['Country','Variable','Date'], suffixes=(False,False))

# %%
df_ASDR_CDR.head()
# Out:
#        Country                                           Variable  Date  \
# 0  Afghanistan                                         All Causes  2000
# 1  Afghanistan  Communicable, maternal, perinatal and nutritio...  2000
# 2  Afghanistan                  Infectious and parasitic diseases  2000
# 3  Afghanistan                                       Tuberculosis  2000
# 4  Afghanistan                                 STDs excluding HIV  2000
#
#    Crude Death Rate  Unnamed: 0  Population Age-standardized Death Rate
# 0       1192.644123         0.0     20094.0                     1617.46
# 1        732.386795       183.0     20094.0                    559.5589
# 2        333.847529       366.0     20094.0                    315.0906
# 3         69.478187       549.0     20094.0                    170.7152
# 4          7.780710       732.0     20094.0                    3.567795

# %%
df_ASDR_CDR2=df_ASDR_CDR.drop(columns=['Unnamed: 0'])

# %%
list(df_ASDR_CDR2)
# Out:
# ['Country',
#  'Variable',
#  'Date',
#  'Crude Death Rate',
#  'Population',
#  'Age-standardized Death Rate']

# %%
df_ASDR_CDR2.to_csv('Output_files/ASDR_CDR_merge_tableau.csv')
